# %%
x = 12

# %%
x
# Out:
# 12

# %% [markdown]
# # Eksamen

# %%
def foo():
    return 12

# %%
foo()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 foo()
#
# NameError: name 'foo' is not defined
